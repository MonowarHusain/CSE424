# %% [markdown]
# <a href="https://colab.research.google.com/github/MonowarHusain/CSE424/blob/main/lab/lab01/Pandas_for_ML_Tabular_Preprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#from google.colab import drive
#drive.mount('/content/drive')

# %%
import pandas as pd
import numpy as np

homelessness = pd.read_csv("https://raw.githubusercontent.com/labib15/Machine-Learning-Datasets/main/homelessness.csv")  #reading a csv file into a dataframe named homelessness
volunteer = pd.read_csv("https://raw.githubusercontent.com/labib15/Machine-Learning-Datasets/main/volunteer_opportunities.csv")
sales = pd.read_csv('https://raw.githubusercontent.com/labib15/Machine-Learning-Datasets/main/sales.csv')
hiking = pd.read_json('https://raw.githubusercontent.com/labib15/Machine-Learning-Datasets/main/hiking.json')
#wards = pd.read_csv("/content/drive/MyDrive/U   N   I/Machine Learning/Code/Dataset/wards.csv",delimiter = ",")

# %% [markdown]
# ## Checking the Dataframe
#
#
# ```
# 1. head(no. of rows) = Shows the selected no. of rows/ samples in the dataframe from the BEGINNING. Default: 5
# 2. tail(no. of rows) = Shows the selected no. of rows / samples in the dataframe from the END.  Default: 5
# 3. shape = row and column number
# 4. columns = name of columns
# 5. info() = data type of each column
# 6. describe() = mean, median, std, etc info about each column
# 7. values = values in the 2d list.
# 8. value_counts() = number of each type in a particular column
# ```

# %%
homelessness.head() #show the first 5 rows
# Out:
#    Unnamed: 0              region       state  individuals  family_members  \
# 0           0  East South Central     Alabama       2570.0           864.0
# 1           1             Pacific      Alaska       1434.0           582.0
# 2           2            Mountain     Arizona       7259.0          2606.0
# 3           3  West South Central    Arkansas       2280.0           432.0
# 4           4             Pacific  California     109008.0         20964.0
#
#    state_pop
# 0    4887681
# 1     735139
# 2    7158024
# 3    3009733
# 4   39461588

# %%
homelessness.head(10)   #shows the first 10 rows
# Out:
#    Unnamed: 0              region                 state  individuals  \
# 0           0  East South Central               Alabama       2570.0
# 1           1             Pacific                Alaska       1434.0
# 2           2            Mountain               Arizona       7259.0
# 3           3  West South Central              Arkansas       2280.0
# 4           4             Pacific            California     109008.0
# 5           5            Mountain              Colorado       7607.0
# 6           6         New England           Connecticut       2280.0
# 7           7      South Atlantic              Delaware        708.0
# 8           8      South Atlantic  District of Columbia       3770.0
# 9           9      South Atlantic               Florida      21443.0
#
#    family_members  state_pop
# 0           864.0    4887681
# 1           582.0     735139
# 2          2606.0    7158024
# 3           432.0    3009733
# 4         20964.0   39461588
# ...

# %%
homelessness.tail()
# Out:
#     Unnamed: 0              region          state  individuals  \
# 46          46      South Atlantic       Virginia       3928.0
# 47          47             Pacific     Washington      16424.0
# 48          48      South Atlantic  West Virginia       1021.0
# 49          49  East North Central      Wisconsin       2740.0
# 50          50            Mountain        Wyoming        434.0
#
#     family_members  state_pop
# 46          2047.0    8501286
# 47          5880.0    7523869
# 48           222.0    1804291
# 49          2167.0    5807406
# 50           205.0     577601

# %%
homelessness.tail(10)
# Out:
#     Unnamed: 0              region          state  individuals  \
# 41          41  West North Central   South Dakota        836.0
# 42          42  East South Central      Tennessee       6139.0
# 43          43  West South Central          Texas      19199.0
# 44          44            Mountain           Utah       1904.0
# 45          45         New England        Vermont        780.0
# 46          46      South Atlantic       Virginia       3928.0
# 47          47             Pacific     Washington      16424.0
# 48          48      South Atlantic  West Virginia       1021.0
# 49          49  East North Central      Wisconsin       2740.0
# 50          50            Mountain        Wyoming        434.0
#
#     family_members  state_pop
# 41           323.0     878698
# 42          1744.0    6771631
# 43          6111.0   28628666
# 44           972.0    3153550
# 45           511.0     624358
# 46          2047.0    8501286
# 47          5880.0    7523869
# ...

# %%
print(homelessness.shape)
print(homelessness.columns)
# Out:
# (51, 6)
# Index(['Unnamed: 0', 'region', 'state', 'individuals', 'family_members',
#        'state_pop'],
#       dtype='object')

# %%
print(homelessness.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      51 non-null     int64
#  1   region          51 non-null     object
#  2   state           51 non-null     object
#  3   individuals     51 non-null     float64
#  4   family_members  51 non-null     float64
#  5   state_pop       51 non-null     int64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 2.5+ KB
# None

# %%
print(homelessness.describe())
# Out:
#        Unnamed: 0    individuals  family_members     state_pop
# count   51.000000      51.000000       51.000000  5.100000e+01
# mean    25.000000    7225.784314     3504.882353  6.405637e+06
# std     14.866069   15991.025083     7805.411811  7.327258e+06
# min      0.000000     434.000000       75.000000  5.776010e+05
# 25%     12.500000    1446.500000      592.000000  1.777414e+06
# 50%     25.000000    3082.000000     1482.000000  4.461153e+06
# 75%     37.500000    6781.500000     3196.000000  7.340946e+06
# max     50.000000  109008.000000    52070.000000  3.946159e+07

# %% [markdown]
# ## Subsetting Columns/Features

# %%
#Subsetting one column
r = homelessness[["region"]]
r.head()
# Out:
#                region
# 0  East South Central
# 1             Pacific
# 2            Mountain
# 3  West South Central
# 4             Pacific

# %%
#Subsetting multiple columns
r_f = homelessness[["region","family_members"]]
r_f.head()
# Out:
#                region  family_members
# 0  East South Central           864.0
# 1             Pacific           582.0
# 2            Mountain          2606.0
# 3  West South Central           432.0
# 4             Pacific         20964.0

# %% [markdown]
# ### **value_counts()**  --> Used to give count for each values for a specified column

# %%
homelessness["region"].value_counts()
# Out:
# region
# South Atlantic        9
# Mountain              8
# West North Central    7
# New England           6
# East North Central    5
# Pacific               5
# East South Central    4
# West South Central    4
# Mid-Atlantic          3
# Name: count, dtype: int64

# %%
homelessness["region"].value_counts(ascending = False)  #ascending = True (default)
# Out:
# region
# South Atlantic        9
# Mountain              8
# West North Central    7
# New England           6
# East North Central    5
# Pacific               5
# East South Central    4
# West South Central    4
# Mid-Atlantic          3
# Name: count, dtype: int64

# %%
homelessness["region"].value_counts(normalize = True) #normalize = False (default).
# Out:
# region
# South Atlantic        0.176471
# Mountain              0.156863
# West North Central    0.137255
# New England           0.117647
# East North Central    0.098039
# Pacific               0.098039
# East South Central    0.078431
# West South Central    0.078431
# Mid-Atlantic          0.058824
# Name: proportion, dtype: float64

# %% [markdown]
# ## Subsetting Rows

# %% [markdown]
# **Comparison Operation**

# %%
fam_less_than_1k_boolean = homelessness["family_members"]<1000
fam_less_than_1k_boolean.head()
# Out:
# 0     True
# 1     True
# 2    False
# 3     True
# 4    False
# Name: family_members, dtype: bool

# %%
fam_less_than_1k = homelessness[homelessness["family_members"]<1000]
fam_less_than_1k.head()
# Out:
#     Unnamed: 0              region     state  individuals  family_members  \
# 0            0  East South Central   Alabama       2570.0           864.0
# 1            1             Pacific    Alaska       1434.0           582.0
# 3            3  West South Central  Arkansas       2280.0           432.0
# 7            7      South Atlantic  Delaware        708.0           374.0
# 12          12            Mountain     Idaho       1297.0           715.0
#
#     state_pop
# 0     4887681
# 1      735139
# 3     3009733
# 7      965479
# 12    1750536

# %%
mountain_reg = homelessness[homelessness["region"]=="Mountain"]
mountain_reg.head()
# Out:
#     Unnamed: 0    region     state  individuals  family_members  state_pop
# 2            2  Mountain   Arizona       7259.0          2606.0    7158024
# 5            5  Mountain  Colorado       7607.0          3250.0    5691287
# 12          12  Mountain     Idaho       1297.0           715.0    1750536
# 26          26  Mountain   Montana        983.0           422.0    1060665
# 28          28  Mountain    Nevada       7058.0           486.0    3027341

# %%
not_mountain_reg = homelessness[homelessness["region"]!="Mountain"]
not_mountain_reg.head()
# Out:
#    Unnamed: 0              region        state  individuals  family_members  \
# 0           0  East South Central      Alabama       2570.0           864.0
# 1           1             Pacific       Alaska       1434.0           582.0
# 3           3  West South Central     Arkansas       2280.0           432.0
# 4           4             Pacific   California     109008.0         20964.0
# 6           6         New England  Connecticut       2280.0          1696.0
#
#    state_pop
# 0    4887681
# 1     735139
# 3    3009733
# 4   39461588
# 6    3571520

# %% [markdown]
# **Logical Operator**

# %%
fam_and_reg = homelessness[(homelessness["family_members"]<1000) & (homelessness["region"]=="Mountain")]
fam_and_reg.head()
# Out:
#     Unnamed: 0    region       state  individuals  family_members  state_pop
# 12          12  Mountain       Idaho       1297.0           715.0    1750536
# 26          26  Mountain     Montana        983.0           422.0    1060665
# 28          28  Mountain      Nevada       7058.0           486.0    3027341
# 31          31  Mountain  New Mexico       1949.0           602.0    2092741
# 44          44  Mountain        Utah       1904.0           972.0    3153550

# %%
fam_or_reg = homelessness[(homelessness["family_members"]<1000) | (homelessness["region"]=="Mountain")]
fam_or_reg.head()
# Out:
#    Unnamed: 0              region     state  individuals  family_members  \
# 0           0  East South Central   Alabama       2570.0           864.0
# 1           1             Pacific    Alaska       1434.0           582.0
# 2           2            Mountain   Arizona       7259.0          2606.0
# 3           3  West South Central  Arkansas       2280.0           432.0
# 5           5            Mountain  Colorado       7607.0          3250.0
#
#    state_pop
# 0    4887681
# 1     735139
# 2    7158024
# 3    3009733
# 5    5691287

# %%
reg_or= homelessness[homelessness["region"].isin(["Mountain","Pacific"])]
reg_or.head()
# Out:
#     Unnamed: 0    region       state  individuals  family_members  state_pop
# 1            1   Pacific      Alaska       1434.0           582.0     735139
# 2            2  Mountain     Arizona       7259.0          2606.0    7158024
# 4            4   Pacific  California     109008.0         20964.0   39461588
# 5            5  Mountain    Colorado       7607.0          3250.0    5691287
# 11          11   Pacific      Hawaii       4131.0          2399.0    1420593

# %% [markdown]
# ## Adding New Columns

# %%
homelessness.head()
# Out:
#    Unnamed: 0              region       state  individuals  family_members  \
# 0           0  East South Central     Alabama       2570.0           864.0
# 1           1             Pacific      Alaska       1434.0           582.0
# 2           2            Mountain     Arizona       7259.0          2606.0
# 3           3  West South Central    Arkansas       2280.0           432.0
# 4           4             Pacific  California     109008.0         20964.0
#
#    state_pop
# 0    4887681
# 1     735139
# 2    7158024
# 3    3009733
# 4   39461588

# %%
homelessness["total"] = homelessness["individuals"] + homelessness["family_members"]
homelessness.head()
# Out:
#    Unnamed: 0              region       state  individuals  family_members  \
# 0           0  East South Central     Alabama       2570.0           864.0
# 1           1             Pacific      Alaska       1434.0           582.0
# 2           2            Mountain     Arizona       7259.0          2606.0
# 3           3  West South Central    Arkansas       2280.0           432.0
# 4           4             Pacific  California     109008.0         20964.0
#
#    state_pop     total
# 0    4887681    3434.0
# 1     735139    2016.0
# 2    7158024    9865.0
# 3    3009733    2712.0
# 4   39461588  129972.0

# %%
homelessness["p_individuals"] = homelessness["individuals"]/homelessness["total"]
homelessness.head()
# Out:
#    Unnamed: 0              region       state  individuals  family_members  \
# 0           0  East South Central     Alabama       2570.0           864.0
# 1           1             Pacific      Alaska       1434.0           582.0
# 2           2            Mountain     Arizona       7259.0          2606.0
# 3           3  West South Central    Arkansas       2280.0           432.0
# 4           4             Pacific  California     109008.0         20964.0
#
#    state_pop     total  p_individuals
# 0    4887681    3434.0       0.748398
# 1     735139    2016.0       0.711310
# 2    7158024    9865.0       0.735834
# 3    3009733    2712.0       0.840708
# 4   39461588  129972.0       0.838704

# %% [markdown]
# ## Checking Null Values
#
#
#
#
#
# `Here we are taking a new dataframe called 'volunteer'`

# %%
volunteer.shape
# Out:
# (665, 35)

# %%
volunteer.head()
# Out:
#    opportunity_id  content_id  vol_requests  event_time  \
# 0            4996       37004            50           0
# 1            5008       37036             2           0
# 2            5016       37143            20           0
# 3            5022       37237           500           0
# 4            5055       37425            15           0
#
#                                                title  hits  \
# 0  Volunteers Needed For Rise Up & Stay Put! Home...   737
# 1                                       Web designer    22
# 2      Urban Adventures - Ice Skating at Lasker Rink    62
# 3  Fight global hunger and support women farmers ...    14
# 4                                      Stop 'N' Swap    31
#
#                                              summary is_priority  category_id  \
# 0  Building on successful events last summer and ...         NaN          NaN
# 1             Build a website for an Afghan business         NaN          1.0
# ...

# %%
volunteer.isnull()
# Out:
#      opportunity_id  content_id  vol_requests  event_time  title   hits  \
# 0             False       False         False       False  False  False
# 1             False       False         False       False  False  False
# 2             False       False         False       False  False  False
# 3             False       False         False       False  False  False
# 4             False       False         False       False  False  False
# ..              ...         ...           ...         ...    ...    ...
# 660           False       False         False       False  False  False
# 661           False       False         False       False  False  False
# 662           False       False         False       False  False  False
# 663           False       False         False       False  False  False
# 664           False       False         False       False  False  False
#
#      summary  is_priority  category_id  category_desc  ...  end_date_date  \
# ...

# %%
volunteer.isnull().sum()  #We implement this to know how many null values are in each columns of the "volunteer" dataframe
# Out:
# opportunity_id          0
# content_id              0
# vol_requests            0
# event_time              0
# title                   0
# hits                    0
# summary                 0
# is_priority           603
# category_id            48
# category_desc          48
# amsl                  665
# amsl_unit             665
# org_title               0
# org_content_id          0
# addresses_count         0
# locality               70
# region                  0
# postalcode              6
# primary_loc           665
# display_url             0
# recurrence_type         0
# hours                   0
# created_date            0
# last_modified_date      0
# start_date_date         0
# end_date_date           0
# status                  0
# Latitude              665
# Longitude             665
# Community Board       665
# Community Council     665
# Census Tract          665
# BIN                   665
# BBL                   665
# NTA                   665
# dtype: int64

# %%
volunteer["locality"].isnull()
# Out:
# 0       True
# 1      False
# 2       True
# 3       True
# 4       True
#        ...
# 660    False
# 661    False
# 662    False
# 663    False
# 664    False
# Name: locality, Length: 665, dtype: bool

# %%
volunteer["locality"].isnull().sum()
# Out:
# np.int64(70)

# %% [markdown]
# ---
#
#
#
# ---
# #Handling null values:
#
# ---
#
#
#
# ---

# %% [markdown]
# ## Way 1: Dropping Rows - The wrong way (Avoid this)

# %%
volunteer.shape
# Out:
# (665, 35)

# %%
new_volunteer = volunteer.dropna()

# %%
new_volunteer.shape
# Out:
# (0, 35)

# %%
volunteer.shape
# Out:
# (665, 35)

# %%
new_volunteer2 = volunteer["category_id"].dropna()
new_volunteer2.shape
# Out:
# (617,)

# %% [markdown]
# ## Way 2: Dropping a desired column - Better Approach (Follow this)
#
#
# [Pandas Documentation](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.drop.html)
#
# `
# .drop(columns = [column_name], inplace = False)
# `
#
#
# > columns ▶ names of the columns to drop given as list
#
# > inplace ▶ false (default). Have to be set `true` if the column needed to be drop from original dataframe.

# %%
new_volunteer3 = volunteer.drop(columns = ['primary_loc'],inplace = True)  #inplace = False (by default), hence the column was not dropped from the original dataframe 'volunteer'

# %%
volunteer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 665 entries, 0 to 664
# Data columns (total 34 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   opportunity_id      665 non-null    int64
#  1   content_id          665 non-null    int64
#  2   vol_requests        665 non-null    int64
#  3   event_time          665 non-null    int64
#  4   title               665 non-null    object
#  5   hits                665 non-null    int64
#  6   summary             665 non-null    object
#  7   is_priority         62 non-null     object
#  8   category_id         617 non-null    float64
#  9   category_desc       617 non-null    object
#  10  amsl                0 non-null      float64
#  11  amsl_unit           0 non-null      float64
#  12  org_title           665 non-null    object
#  13  org_content_id      665 non-null    int64
#  14  addresses_count     665 non-null    int64
# ...

# %%
new_volunteer3.info()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-3629453297.py in <cell line: 0>()
# ----> 1 new_volunteer3.info()
#
# AttributeError: 'NoneType' object has no attribute 'info'

# %% [markdown]
# ## Way 3: Imputing values instead of null values

# %% [markdown]
# ### Option 1: Directly Assign a value of our choice
#
#
#
#
#
# > Without inplace imputing

# %%
volunteer["BIN"].isnull().sum()

# %%
volunteer["BIN"].fillna(10)

# %%
volunteer["BIN"].isnull().sum()  #the rows in "BIN" column still have null features.

# %% [markdown]
# > inplace imputing values (2 Ways)

# %%
#volunteer["BIN"].fillna(10, inplace = True)

# %%
#volunteer["BIN"] = volunteer["BIN"].fillna(10)

# %%
volunteer["BIN"].isnull().sum()

# %% [markdown]
# ### Option 2: Using SimpleImputer to estimate a value for null values using existing values in the column

# %%
sales.head()

# %%
sales['salt'].isnull().sum()

# %%
from sklearn.impute import SimpleImputer

impute = SimpleImputer(missing_values=np.nan, strategy='mean')

impute.fit(sales[['salt']])

sales['salt'] = impute.transform(sales[['salt']])  #Here we are making sure it is inplace = True

# %%
sales['salt'].isnull().sum()

# %% [markdown]
# # Handling Categorical / Text Data
#
# There are two types of text data we might come across.
#
#
# *   Nominal - Not ordered. Non Heirchical. No ranking of one above another. For eg. names of countries, places, foods.
# *   Ordinal - Ordered. Heirchical. Ranking of one above another. For eg. True / False, Best/Average/Worst

# %% [markdown]
# ### Option 1: Nominal (No Ranking)
#
#
# `
# One hot encoding
# `

# %%
volunteer['category_desc'].unique()

# %%
# Transform the category_desc column
category_enc = pd.get_dummies(volunteer['category_desc'])

# Take a look at the encoded columns
category_enc.head()

# %% [markdown]
# ### Option 2: Ordinal (Ranking)

# %%
hiking.head()

# %% [markdown]
# > **Using LabelEncoder**

# %%
from sklearn.preprocessing import LabelEncoder

# Set up the LabelEncoder object
enc = LabelEncoder()

# Apply the encoding to the "Accessible" column
hiking['Accessible_enc'] = enc.fit_transform(hiking['Accessible'])   # Here we are not changing inplace

# Compare the two columns
print(hiking[['Accessible', 'Accessible_enc']].head())

# %% [markdown]
# > **Using map**

# %%
hiking['Accessible'] = hiking['Accessible'].map({'Y':1,'N':0})

# %% [markdown]
# # Dropping column due to correlation

# %%
from sklearn.datasets import load_wine

wine = load_wine()
wine_df = pd.DataFrame( wine['data'], columns=wine['feature_names'])

# %%
wine_df.head()

# %%
wine_corr = wine_df.corr()
wine_corr

# %%
import seaborn as sns

sns.heatmap(wine_corr, cmap = 'YlGnBu')

# %%
# Take a minute to find the column where the correlation value is greater than 0.75 at least twice
to_drop = 'flavanoids'

# Drop that column from the DataFrame
wine_df = wine_df.drop(columns = to_drop)

# %%
wine_df.columns   #no 'flavanoids' column present

# %% [markdown]
# ---
#
#
# # Scaling or Normalization
#
# ## Why do we need to scale our data?
# * If a feature’s variance is orders of magnitude more than the variance of other features, that particular feature might dominate other features in the dataset and make the estimator unable to learn from other features correctly, i.e. our learner might give more importance to features with high variance, which is not something we want happening in our model.
#
# The following are a few different types of Scalers:
#
# ----
#
#
# **MinMax Scaler:**
#
# Scales values to a range between 0 and 1 if no negative values, and -1 to 1 if there are negative values present.
#
# $$\frac{X - X_{min}}{X_{max} - X_{min}}$$
#
# where,
#
#  $$X\space is\space a\space feature\space value.$$
#  $$X_{min} \space and \space X_{max} \space are \space corresponding \space feature's \space min \space and \space max \space values. $$
#
#
# **Standard Scaler:**
#
# $$\frac{X - mean}{\sigma}$$
# where,
# $$\sigma = standard \space deviation $$
#
# **Robust Scaler:**
#
# Uses statistics that are robust to outliers
#
# $$\frac{X - median}{IQR}$$
#
# where,
#
# $$ IQR = Inter\space Quartile\space Range = Q_3 - Q_1 $$

# %%
from sklearn.datasets import load_breast_cancer
from sklearn.preprocessing import StandardScaler
import pandas as pd

# Load the breast cancer dataset
data_cancer = load_breast_cancer()
df = pd.DataFrame(data_cancer.data, columns=data_cancer.feature_names)

# Initialize the StandardScaler
scaler = StandardScaler()

# Fit and transform the data
scaled_data = scaler.fit_transform(df)

# Create a new DataFrame with the scaled data
scaled_df = pd.DataFrame(scaled_data, columns=data.feature_names)

# Print the scaled DataFrame (optional)
print(scaled_df.head())

# %% [markdown]
# # Train-Test Split
# [Sk-Learn Documentation](https://scikit-learn.org/1.5/modules/generated/sklearn.model_selection.train_test_split.html)

# %%
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split

cancer = load_breast_cancer()

X_train, X_test, y_train, y_test = train_test_split(cancer.data, cancer.target, test_size = 0.20, stratify = cancer.target, random_state=1)

# %%
# prompt: logistic regression using sklearn

from sklearn.linear_model import LogisticRegression

# Initialize the Logistic Regression model
log_reg = LogisticRegression()

# Train the model
log_reg.fit(X_train, y_train)

# Make predictions on the test set
y_pred = log_reg.predict(X_test)

# Evaluate the model (example: accuracy)
from sklearn.metrics import accuracy_score
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy}")

# %%
# prompt: sklearn implementation of naive bayes

from sklearn.naive_bayes import GaussianNB

# Assuming X_train, X_test, y_train, y_test are already defined from the previous code

# Initialize the Gaussian Naive Bayes model
gnb = GaussianNB()

# Train the model
gnb.fit(X_train, y_train)

# Make predictions on the test set
y_pred_gnb = gnb.predict(X_test)

# Evaluate the model (example: accuracy)
accuracy_gnb = accuracy_score(y_test, y_pred_gnb)
print(f"Gaussian Naive Bayes Accuracy: {accuracy_gnb}")

# %%
from sklearn.tree import DecisionTreeClassifier

dt = DecisionTreeClassifier()

dt.fit(X_train, y_train)

y_pred_dt = dt.predict(X_test)

accuracy_dt = accuracy_score(y_test, y_pred_dt)
print(f"Decision Tree Accuracy: {accuracy_dt}")

# %%
# prompt: use the model random forest for the  same dataset

from sklearn.ensemble import RandomForestClassifier

# Assuming X_train, X_test, y_train, y_test are already defined from the previous code

# Initialize the Random Forest model
rf = RandomForestClassifier(n_estimators=100, random_state=1)

# Train the model
rf.fit(X_train, y_train)

# Make predictions on the test set
y_pred_rf = rf.predict(X_test)

# Evaluate the model (example: accuracy)
accuracy_rf = accuracy_score(y_test, y_pred_rf)
print(f"Random Forest Accuracy: {accuracy_rf}")
